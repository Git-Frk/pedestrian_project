# %% [markdown]
# # QA - Fidelity (Test_NB)
#
# This notebook is to find a threshold value for the similarity score to remove bad quality images - based on qualitative analysis of the original image and translated image.
#
# The cosine similarity of the image embeddings is computed using two pretrianed models:
# 1. CLIP
# 2. DINOv2

# %% [markdown]
# ## CLIP

# %%
from clip_sim import clip_similarity
# Out:
# 2024-02-13 13:37:10.067064: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-13 13:37:12.339259: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#clip_similarity(original_image path, 'translated_image path')

clip_similarity('./Images2test/Original-Night/imgn14.png', './Images2test/Translated-Night/imgn_14.png')
# Out:
# Similarity: 0.8722911775112152

# %% [markdown]
# ## DINOv2

# %%
from dinov2_sim import dinov2_similarity

# %%
#dinov2_similarity(original_image path, 'translated_image path')

dinov2_similarity('./Images2test/Original-Night/imgn14.png', './Images2test/Translated-Night/imgn_14.png')
# Out:
# Similarity: 0.9203760921955109
